# %% [markdown]
# <a href="https://colab.research.google.com/github/gmpravin/10DaysMLChallange-Coronoviras/blob/master/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("time_series_2019-ncov-Confirmed.csv");

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat  ...  3/20/20  3/21/20  3/22/20
# 0            NaN       Thailand  15.0000  ...      322      411      599
# 1            NaN          Japan  36.0000  ...      963     1007     1086
# 2            NaN      Singapore   1.2833  ...      385      432      455
# 3            NaN          Nepal  28.1667  ...        1        1        2
# 4            NaN       Malaysia   2.5000  ...     1030     1183     1306
#
# [5 rows x 65 columns]

# %%
df.describe()
# Out:
#               Lat        Long  ...       3/21/20       3/22/20
# count  487.000000  487.000000  ...    487.000000    487.000000
# mean    30.580962  -33.601551  ...    625.305955    689.845996
# std     19.645817   81.064011  ...   4397.961371   4658.551576
# min    -41.454500 -157.858400  ...      0.000000      0.000000
# 25%     24.000000  -91.733100  ...      0.000000      0.000000
# 50%     37.545500  -73.794900  ...      3.000000      4.000000
# 75%     42.171200   22.380900  ...    125.000000    138.500000
# max     71.706900  178.065000  ...  67800.000000  67800.000000
#
# [8 rows x 63 columns]

# %%
df.describe()
# Out:
#               Lat        Long  ...       3/21/20       3/22/20
# count  487.000000  487.000000  ...    487.000000    487.000000
# mean    30.580962  -33.601551  ...    625.305955    689.845996
# std     19.645817   81.064011  ...   4397.961371   4658.551576
# min    -41.454500 -157.858400  ...      0.000000      0.000000
# 25%     24.000000  -91.733100  ...      0.000000      0.000000
# 50%     37.545500  -73.794900  ...      3.000000      4.000000
# 75%     42.171200   22.380900  ...    125.000000    138.500000
# max     71.706900  178.065000  ...  67800.000000  67800.000000
#
# [8 rows x 63 columns]

# %%
region=df['Country/Region']

# %%
region
# Out:
# 0         Thailand
# 1            Japan
# 2        Singapore
# 3            Nepal
# 4         Malaysia
#           ...
# 482       Dominica
# 483        Grenada
# 484     Mozambique
# 485          Syria
# 486    Timor-Leste
# Name: Country/Region, Length: 487, dtype: object

# %%
 particular_date=df['1/22/20']

# %%
print(particular_date)
# Out:
# 0      2
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 482    0
# 483    0
# 484    0
# 485    0
# 486    0
# Name: 1/22/20, Length: 487, dtype: int64

# %%
percent=df[df==0].count(axis=0)/len(df.index)

# %%
percent
# Out:
# Province/State    0.000000
# Country/Region    0.000000
# Lat               0.000000
# Long              0.000000
# 1/22/20           0.940452
#                     ...
# 3/18/20           0.445585
# 3/19/20           0.433265
# 3/20/20           0.414784
# 3/21/20           0.404517
# 3/22/20           0.394251
# Length: 65, dtype: float64

# %%
db_percent=percent[percent>0.7]

# %%
print(db_percent)
# Out:
# 1/22/20    0.940452
# 1/23/20    0.924025
# 1/24/20    0.917864
# 1/25/20    0.911704
# 1/26/20    0.899384
# 1/27/20    0.893224
# 1/28/20    0.891170
# 1/29/20    0.885010
# 1/30/20    0.878850
# 1/31/20    0.868583
# 2/1/20     0.862423
# 2/2/20     0.862423
# 2/3/20     0.860370
# 2/4/20     0.858316
# 2/5/20     0.858316
# 2/6/20     0.858316
# 2/7/20     0.856263
# 2/8/20     0.856263
# 2/9/20     0.856263
# 2/10/20    0.856263
# 2/11/20    0.854209
# 2/12/20    0.854209
# 2/13/20    0.854209
# 2/14/20    0.852156
# 2/15/20    0.852156
# 2/16/20    0.852156
# 2/17/20    0.852156
# 2/18/20    0.852156
# 2/19/20    0.850103
# 2/20/20    0.850103
# 2/21/20    0.839836
# 2/22/20    0.839836
# 2/23/20    0.839836
# 2/24/20    0.827515
# 2/25/20    0.819302
# 2/26/20    0.804928
# 2/27/20    0.796715
# 2/28/20    0.782341
# 2/29/20    0.770021
# 3/1/20     0.757700
# 3/2/20     0.726899
# 3/3/20     0.708419
# dtype: float64

# %%
p1=db_percent.index

# %%
p1
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20'],
#       dtype='object')

# %%
df=df.drop(columns=p1)

# %%
df
# Out:
#     Province/State Country/Region      Lat  ...  3/20/20  3/21/20  3/22/20
# 0              NaN       Thailand  15.0000  ...      322      411      599
# 1              NaN          Japan  36.0000  ...      963     1007     1086
# 2              NaN      Singapore   1.2833  ...      385      432      455
# 3              NaN          Nepal  28.1667  ...        1        1        2
# 4              NaN       Malaysia   2.5000  ...     1030     1183     1306
# ..             ...            ...      ...  ...      ...      ...      ...
# 482            NaN       Dominica  15.4150  ...        0        0        1
# 483            NaN        Grenada  12.1165  ...        0        0        1
# 484            NaN     Mozambique -18.6657  ...        0        0        1
# 485            NaN          Syria  34.8021  ...        0        0        1
# 486            NaN    Timor-Leste  -8.8742  ...        0        0        1
#
# [487 rows x 23 columns]

# %%
df=df.drop(columns=["Lat"])

# %%
df=df.drop(columns=["Long"])

# %%
df.head(20)
# Out:
#       Province/State        Country/Region  3/4/20  ...  3/20/20  3/21/20  3/22/20
# 0                NaN              Thailand      43  ...      322      411      599
# 1                NaN                 Japan     331  ...      963     1007     1086
# 2                NaN             Singapore     110  ...      385      432      455
# 3                NaN                 Nepal       1  ...        1        1        2
# 4                NaN              Malaysia      50  ...     1030     1183     1306
# 5   British Columbia                Canada      12  ...      271      424      424
# 6    New South Wales             Australia      22  ...      353      436      533
# 7           Victoria             Australia      10  ...      121      229      296
# 8         Queensland             Australia      11  ...      184      221      221
# 9                NaN              Cambodia       1  ...       51       53       84
# ...

# %%
df.shape
# Out:
# (487, 21)

# %%
gbs=df.groupby(["Country/Region"],as_index=True).sum()

# %%
gbs
# Out:
#                 3/4/20  3/5/20  3/6/20  ...  3/20/20  3/21/20  3/22/20
# Country/Region                          ...
# Afghanistan          1       1       1  ...       24       24       40
# Albania              0       0       0  ...       70       76       89
# Algeria             12      12      17  ...       90      139      201
# Andorra              1       1       1  ...       75       88      113
# Angola               0       0       0  ...        1        2        2
# ...                ...     ...     ...  ...      ...      ...      ...
# Uzbekistan           0       0       0  ...       33       43       43
# Venezuela            0       0       0  ...       42       70       70
# Vietnam             16      16      16  ...       91       94      113
# Zambia               0       0       0  ...        2        2        3
# Zimbabwe             0       0       0  ...        1        3        3
#
# [171 rows x 19 columns]

# %%
gbs=df.groupby(["Country/Region"],as_index=False).sum()

# %%
gbs
# Out:
#     Country/Region  3/4/20  3/5/20  3/6/20  ...  3/19/20  3/20/20  3/21/20  3/22/20
# 0      Afghanistan       1       1       1  ...       22       24       24       40
# 1          Albania       0       0       0  ...       64       70       76       89
# 2          Algeria      12      12      17  ...       87       90      139      201
# 3          Andorra       1       1       1  ...       53       75       88      113
# 4           Angola       0       0       0  ...        0        1        2        2
# ..             ...     ...     ...     ...  ...      ...      ...      ...      ...
# 166     Uzbekistan       0       0       0  ...       23       33       43       43
# 167      Venezuela       0       0       0  ...       42       42       70       70
# 168        Vietnam      16      16      16  ...       85       91       94      113
# 169         Zambia       0       0       0  ...        2        2        2        3
# ...

# %% [markdown]
# //return last n no of rows

# %%
df.tail()
# Out:
#     Province/State Country/Region  3/4/20  ...  3/20/20  3/21/20  3/22/20
# 482            NaN       Dominica       0  ...        0        0        1
# 483            NaN        Grenada       0  ...        0        0        1
# 484            NaN     Mozambique       0  ...        0        0        1
# 485            NaN          Syria       0  ...        0        0        1
# 486            NaN    Timor-Leste       0  ...        0        0        1
#
# [5 rows x 21 columns]

# %%
data=df.drop(columns=["Province/State"])
data.head()
# Out:
#   Country/Region  3/4/20  3/5/20  3/6/20  ...  3/19/20  3/20/20  3/21/20  3/22/20
# 0       Thailand      43      47      48  ...      272      322      411      599
# 1          Japan     331     360     420  ...      924      963     1007     1086
# 2      Singapore     110     117     130  ...      345      385      432      455
# 3          Nepal       1       1       1  ...        1        1        1        2
# 4       Malaysia      50      50      83  ...      900     1030     1183     1306
#
# [5 rows x 20 columns]

# %%
df2=data.copy()

# %%
dcols=list(data.columns)

# %%
dcols
# Out:
# ['Country/Region',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20']

# %%
rowsum=df2.sum(axis=1)

# %%
rowsum
# Out:
# 0       2881
# 1      13329
# 2       4388
# 3         20
# 4       8230
#        ...
# 482        1
# 483        1
# 484        1
# 485        1
# 486        1
# Length: 487, dtype: int64

# %%
df2["Totel "]=rowsum
df2.head()
# Out:
#   Country/Region  3/4/20  3/5/20  3/6/20  ...  3/20/20  3/21/20  3/22/20  Totel
# 0       Thailand      43      47      48  ...      322      411      599    2881
# 1          Japan     331     360     420  ...      963     1007     1086   13329
# 2      Singapore     110     117     130  ...      385      432      455    4388
# 3          Nepal       1       1       1  ...        1        1        2      20
# 4       Malaysia      50      50      83  ...     1030     1183     1306    8230
#
# [5 rows x 21 columns]

# %%
country=df2["Country/Region"]
totel=df2["Totel "]
newHeading=["Country","Totel Corono/COVID-19 cases"]
ndf=pd.DataFrame(columns=newHeading)
ndf["Country"]=country
ndf["Totel Corono/COVID-19 cases"]=totel
ndf.head()
# Out:
#      Country  Totel Corono/COVID-19 cases
# 0   Thailand                         2881
# 1      Japan                        13329
# 2  Singapore                         4388
# 3      Nepal                           20
# 4   Malaysia                         8230

# %%
df2
# Out:
#     Country/Region  3/4/20  3/5/20  3/6/20  ...  3/20/20  3/21/20  3/22/20  Totel
# 0         Thailand      43      47      48  ...      322      411      599    2881
# 1            Japan     331     360     420  ...      963     1007     1086   13329
# 2        Singapore     110     117     130  ...      385      432      455    4388
# 3            Nepal       1       1       1  ...        1        1        2      20
# 4         Malaysia      50      50      83  ...     1030     1183     1306    8230
# ..             ...     ...     ...     ...  ...      ...      ...      ...     ...
# 482       Dominica       0       0       0  ...        0        0        1       1
# 483        Grenada       0       0       0  ...        0        0        1       1
# 484     Mozambique       0       0       0  ...        0        0        1       1
# 485          Syria       0       0       0  ...        0        0        1       1
# ...

# %%
ndf.plot(x="Country",y="Totel Corono/COVID-19 cases",kind="bar")
plt.show()

# %%
ndf.plot(x="Country",y="Totel Corono/COVID-19 cases",kind="line")
plt.show()

# %%
top10=ndf.nlargest(10,"Totel Corono/COVID-19 cases")

# %%
top10
# Out:
#             Country  Totel Corono/COVID-19 cases
# 154           China                      1286787
# 16            Italy                       428621
# 155            Iran                       224700
# 18            Spain                       156912
# 156    Korea, South                       147381
# 11          Germany                       135037
# 157          France                       100685
# 99               US                        48745
# 31      Switzerland                        39007
# 403  United Kingdom                        29027

# %%
top10.plot(x="Country",y="Totel Corono/COVID-19 cases",kind="line")
plt.show()

# %%
top10.plot(x="Country",y="Totel Corono/COVID-19 cases",kind="bar")
plt.show()

# %%
india=ndf.loc[ndf["Country"]=="India"]
india
# Out:
#    Country  Totel Corono/COVID-19 cases
# 15   India                         2274

# %%
india.plot(x="Country",y="Totel Corono/COVID-19 cases",kind="bar")
plt.show()

# %%
df3=df2.loc[df2['Country/Region'] == 'Italy']

# %%
df4=df3.drop(columns=["Totel ","Country/Region"])
df4.head()
# Out:
#     3/4/20  3/5/20  3/6/20  3/7/20  ...  3/19/20  3/20/20  3/21/20  3/22/20
# 16    3089    3858    4636    5883  ...    41035    47021    53578    59138
#
# [1 rows x 19 columns]

# %%
dates=list(df4.columns)
dates
# Out:
# ['3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20']

# %%
df4
# Out:
#     3/4/20  3/5/20  3/6/20  3/7/20  ...  3/19/20  3/20/20  3/21/20  3/22/20
# 16    3089    3858    4636    5883  ...    41035    47021    53578    59138
#
# [1 rows x 19 columns]

# %%
cases=[]
for date in dates:
    x=df4.at[16,date]
    cases.append(x)

# %%
dateorder=pd.DataFrame(columns=['dates','cases'])
dateorder['dates']=dates
dateorder['cases']=cases
dateorder
# Out:
#       dates  cases
# 0    3/4/20   3089
# 1    3/5/20   3858
# 2    3/6/20   4636
# 3    3/7/20   5883
# 4    3/8/20   7375
# 5    3/9/20   9172
# 6   3/10/20  10149
# 7   3/11/20  12462
# 8   3/12/20  12462
# 9   3/13/20  17660
# 10  3/14/20  21157
# 11  3/15/20  24747
# 12  3/16/20  27980
# 13  3/17/20  31506
# 14  3/18/20  35713
# 15  3/19/20  41035
# 16  3/20/20  47021
# 17  3/21/20  53578
# 18  3/22/20  59138

# %%
dateorder.plot(x='dates',y='cases',kind='bar',color='green')
plt.ylabel('cases')
plt.title('Italy\'s Covid-19 cases/date')
plt.show()

# %%
continents = pd.read_csv("continent.csv", sep=',')

# %%
print(continents)
# Out:
#          Continent    Country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
merged_df = pd.merge(left=df2, right=continents, left_on='Country/Region', right_on='Country')

# %%
merged_df
# Out:
#     Country/Region  3/4/20  3/5/20  ...  Totel       Continent     Country
# 0         Thailand      43      47  ...    2881           Asia    Thailand
# 1            Japan     331     360  ...   13329           Asia       Japan
# 2        Singapore     110     117  ...    4388           Asia   Singapore
# 3            Nepal       1       1  ...      20           Asia       Nepal
# 4         Malaysia      50      50  ...    8230           Asia    Malaysia
# ..             ...     ...     ...  ...     ...            ...         ...
# 464         Uganda       0       0  ...       2         Africa      Uganda
# 465       Dominica       0       0  ...       1  North America    Dominica
# 466        Grenada       0       0  ...       1  North America     Grenada
# 467     Mozambique       0       0  ...       1         Africa  Mozambique
# 468          Syria       0       0  ...       1           Asia       Syria
#
# [469 rows x 23 columns]

# %%
merged1 = merged_df.groupby(['Continent'],as_index=False).sum()

# %%
merged1
# Out:
#        Continent  3/4/20  3/5/20  3/6/20  ...  3/20/20  3/21/20  3/22/20   Totel
# 0         Africa      21      24      43  ...      896     1064     1299     6762
# 1           Asia   84123   84927   86461  ...   108351   110856   113760  1832736
# 2         Europe    4336    5736    7493  ...   128470   149774   168121  1045620
# 3  North America     188     260     320  ...    20595    27543    35742   136108
# 4        Oceania      55      58      64  ...      832     1125     1383     7053
# 5  South America      16      22      34  ...     2259     2964     4096    15347
#
# [6 rows x 21 columns]

# %%
top5continents=merged1.nlargest(5,"Totel ")

# %%
h1=top5continents["Continent"]
h2=top5continents["Totel "]
h3=top5continents["3/22/20"]
task3=pd.DataFrame(columns=['Continent','Cases'])
task3['Continent']=h1
task3['Cases']=h2
task3
# Out:
#        Continent    Cases
# 1           Asia  1832736
# 2         Europe  1045620
# 3  North America   136108
# 5  South America    15347
# 4        Oceania     7053

# %%
task3.plot(x='Continent',y='Cases',kind='bar',color='green')
plt.xlabel('Continents')
plt.ylabel('Cases')
plt.title('Continent-wise representation of number of Covid-19 Cases upto 22nd March,2020 ')
plt.show()

# %%
t4=pd.DataFrame(columns=['Continent','Cases'])
t4['Continent']=h1
t4['Cases']=h3
t4
# Out:
#        Continent   Cases
# 1           Asia  113760
# 2         Europe  168121
# 3  North America   35742
# 5  South America    4096
# 4        Oceania    1383

# %%
t4.plot(x='Continent',y='Cases',kind='bar',color='brown')
plt.xlabel('Continents')
plt.ylabel('Cases')
plt.title('Continent-wise representation of number of Covid-19 Cases on 22nd March,2020 ')
plt.show()
